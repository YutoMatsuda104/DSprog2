# %%
import pandas as pd
from itertools import permutations

# CSVファイルのパス
file_path = '/Users/yutomatsuda/Lecture/DSProg2/horse_local.csv'

# CSVファイルを読み込む
df = pd.read_csv(file_path)

# 各馬の1着、2着、3着の予測数の合計を計算
df['total_pred'] = df['first_pred'] + df['second_pred'] + df['third_pred']

# 合計予測数で並べ替え
sorted_df = df.sort_values(by='total_pred', ascending=False)

# トップ100の馬を取得
top_horses = sorted_df.head(100)['house_name'].tolist()

# これらの馬の全ての順列を生成
permutations_of_horses = list(permutations(top_horses, 3))

# 最も人気のある組み合わせトップ10を選択
popular_combinations = permutations_of_horses[:100]

# 結果を表示
for i, combo in enumerate(popular_combinations, 1):
    print(f"{i}. {combo}")
# Out:
# 1. ('スターズオンアース', 'ジャスティンパレス', 'タイトルホルダー')
# 2. ('スターズオンアース', 'ジャスティンパレス', 'タスティエーラ')
# 3. ('スターズオンアース', 'ジャスティンパレス', 'ドウドゥース')
# 4. ('スターズオンアース', 'ジャスティンパレス', 'ディープポンド')
# 5. ('スターズオンアース', 'ジャスティンパレス', 'ソールオリエンス')
# 6. ('スターズオンアース', 'ジャスティンパレス', 'スルーセブンシーズ')
# 7. ('スターズオンアース', 'ジャスティンパレス', 'ウインマリリン')
# 8. ('スターズオンアース', 'ジャスティンパレス', 'シャフリヤール')
# 9. ('スターズオンアース', 'ジャスティンパレス', 'プラダリア')
# 10. ('スターズオンアース', 'ジャスティンパレス', 'アイアンバローズ')
# 11. ('スターズオンアース', 'ジャスティンパレス', 'ライラック')
# 12. ('スターズオンアース', 'ジャスティンパレス', 'ハーパー')
# 13. ('スターズオンアース', 'ジャスティンパレス', 'ホウホウエミーズ')
# 14. ('スターズオンアース', 'ジャスティンパレス', 'ヒートオンビート')
# 15. ('スターズオンアース', 'タイトルホルダー', 'ジャスティンパレス')
# 16. ('スターズオンアース', 'タイトルホルダー', 'タスティエーラ')
# 17. ('スターズオンアース', 'タイトルホルダー', 'ドウドゥース')
# 18. ('スターズオンアース', 'タイトルホルダー', 'ディープポンド')
# 19. ('スターズオンアース', 'タイトルホルダー', 'ソールオリエンス')
# 20. ('スターズオンアース', 'タイトルホルダー', 'スルーセブンシーズ')
# 21. ('スターズオンアース', 'タイトルホルダー', 'ウインマリリン')
# 22. ('スターズオンアース', 'タイトルホルダー', 'シャフリヤール')
# 23. ('スターズオンアース', 'タイトルホルダー', 'プラダリア')
# 24. ('スターズオンアース', 'タイトルホルダー', 'アイアンバローズ')
# 25. ('スターズオンアース', 'タイトルホルダー', 'ライラック')
# 26. ('スターズオンアース', 'タイトルホルダー', 'ハーパー')
# 27. ('スターズオンアース', 'タイトルホルダー', 'ホウホウエミーズ')
# 28. ('スターズオンアース', 'タイトルホルダー', 'ヒートオンビート')
# 69. ('スターズオンアース', 'ディープポンド', 'ホウホウエミーズ')
# 70. ('スターズオンアース', 'ディープポンド', 'ヒートオンビート')
# 71. ('スターズオンアース', 'ソールオリエンス', 'ジャスティンパレス')
# 72. ('スターズオンアース', 'ソールオリエンス', 'タイトルホルダー')
# 73. ('スターズオンアース', 'ソールオリエンス', 'タスティエーラ')
# 74. ('スターズオンアース', 'ソールオリエンス', 'ドウドゥース')
# 75. ('スターズオンアース', 'ソールオリエンス', 'ディープポンド')
# 76. ('スターズオンアース', 'ソールオリエンス', 'スルーセブンシーズ')
# 77. ('スターズオンアース', 'ソールオリエンス', 'ウインマリリン')
# 78. ('スターズオンアース', 'ソールオリエンス', 'シャフリヤール')
# 79. ('スターズオンアース', 'ソールオリエンス', 'プラダリア')
# 80. ('スターズオンアース', 'ソールオリエンス', 'アイアンバローズ')
# 81. ('スターズオンアース', 'ソールオリエンス', 'ライラック')
# 82. ('スターズオンアース', 'ソールオリエンス', 'ハーパー')
# 83. ('スターズオンアース', 'ソールオリエンス', 'ホウホウエミーズ')
# 84. ('スターズオンアース', 'ソールオリエンス', 'ヒートオンビート')
# 85. ('スターズオンアース', 'スルーセブンシーズ', 'ジャスティンパレス')
# 86. ('スターズオンアース', 'スルーセブンシーズ', 'タイトルホルダー')
# 87. ('スターズオンアース', 'スルーセブンシーズ', 'タスティエーラ')
# 88. ('スターズオンアース', 'スルーセブンシーズ', 'ドウドゥース')
# 89. ('スターズオンアース', 'スルーセブンシーズ', 'ディープポンド')
# 90. ('スターズオンアース', 'スルーセブンシーズ', 'ソールオリエンス')
# 91. ('スターズオンアース', 'スルーセブンシーズ', 'ウインマリリン')
# 92. ('スターズオンアース', 'スルーセブンシーズ', 'シャフリヤール')
# 93. ('スターズオンアース', 'スルーセブンシーズ', 'プラダリア')
# 94. ('スターズオンアース', 'スルーセブンシーズ', 'アイアンバローズ')
# 95. ('スターズオンアース', 'スルーセブンシーズ', 'ライラック')
# 96. ('スターズオンアース', 'スルーセブンシーズ', 'ハーパー')
# 97. ('スターズオンアース', 'スルーセブンシーズ', 'ホウホウエミーズ')
# 98. ('スターズオンアース', 'スルーセブンシーズ', 'ヒートオンビート')
# 99. ('スターズオンアース', 'ウインマリリン', 'ジャスティンパレス')
# 100. ('スターズオンアース', 'ウインマリリン', 'タイトルホルダー')

# %%
# 結果をDataFrameに変換
results_df = pd.DataFrame(popular_combinations, columns=['1st Place', '2nd Place', '3rd Place'])

# 結果をCSVファイルとして保存
output_file_path = '/Users/yutomatsuda/Lecture/DSProg2/localdata_top100.csv'
results_df.to_csv(output_file_path, index=False)

print(f"結果は {output_file_path} に保存されました。")
# Out:
# 結果は /Users/yutomatsuda/Lecture/DSProg2/localdata_top100.csv に保存されました。
